# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("E:\\My Courses\\avocado.csv")
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df=df.iloc[:,1:]
df.head()
df.shape
# Out:
# (18249, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
# Date            18249 non-null object
# AveragePrice    18249 non-null float64
# Total Volume    18249 non-null float64
# 4046            18249 non-null float64
# 4225            18249 non-null float64
# 4770            18249 non-null float64
# Total Bags      18249 non-null float64
# Small Bags      18249 non-null float64
# Large Bags      18249 non-null float64
# XLarge Bags     18249 non-null float64
# type            18249 non-null object
# year            18249 non-null int64
# region          18249 non-null object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
df.head(10)
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# 5  2015-11-22          1.26      55979.78  1184.27   48067.99   43.61
# 6  2015-11-15          0.99      83453.76  1368.92   73672.72   93.26
# 7  2015-11-08          0.98     109428.33   703.75  101815.36   80.00
# 8  2015-11-01          1.02      99811.42  1022.15   87315.57   85.34
# 9  2015-10-25          1.07      74338.76   842.40   64757.44  113.00
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# ...

# %%
df=df.replace(0,pd.np.nan)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
# Date            18249 non-null object
# AveragePrice    18249 non-null float64
# Total Volume    18249 non-null float64
# 4046            18007 non-null float64
# 4225            18188 non-null float64
# 4770            12752 non-null float64
# Total Bags      18234 non-null float64
# Small Bags      18090 non-null float64
# Large Bags      15879 non-null float64
# XLarge Bags     6201 non-null float64
# type            18249 non-null object
# year            18249 non-null int64
# region          18249 non-null object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
df=df.drop("XLarge Bags",axis=1)
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags          type  year  region
# 0     8696.87     8603.62       93.25  conventional  2015  Albany
# 1     9505.56     9408.07       97.49  conventional  2015  Albany
# 2     8145.35     8042.21      103.14  conventional  2015  Albany
# 3     5811.16     5677.40      133.76  conventional  2015  Albany
# 4     6183.95     5986.26      197.69  conventional  2015  Albany

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 12 columns):
# Date            18249 non-null object
# AveragePrice    18249 non-null float64
# Total Volume    18249 non-null float64
# 4046            18007 non-null float64
# 4225            18188 non-null float64
# 4770            12752 non-null float64
# Total Bags      18234 non-null float64
# Small Bags      18090 non-null float64
# Large Bags      15879 non-null float64
# type            18249 non-null object
# year            18249 non-null int64
# region          18249 non-null object
# dtypes: float64(8), int64(1), object(3)
# memory usage: 1.7+ MB

# %%
#we need to fill the nans .
#we need to know we will fill with any value.
df_median = df.median()
df_median
# Out:
# AveragePrice         1.370
# Total Volume    107376.760
# 4046              9273.690
# 4225             29502.355
# 4770              1653.105
# Total Bags       39812.060
# Small Bags       27116.185
# Large Bags        4523.980
# year              2016.000
# dtype: float64

# %%
df.fillna(df_median,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 12 columns):
# Date            18249 non-null object
# AveragePrice    18249 non-null float64
# Total Volume    18249 non-null float64
# 4046            18249 non-null float64
# 4225            18249 non-null float64
# 4770            18249 non-null float64
# Total Bags      18249 non-null float64
# Small Bags      18249 non-null float64
# Large Bags      18249 non-null float64
# type            18249 non-null object
# year            18249 non-null int64
# region          18249 non-null object
# dtypes: float64(8), int64(1), object(3)
# memory usage: 1.7+ MB

# %%
df.rename(columns={'4046':'small Hass','4225':'larg Hass','4770':'extra large Hass'},inplace=True)
df.head()
# Out:
#          Date  AveragePrice  Total Volume  small Hass  larg Hass  \
# 0  2015-12-27          1.33      64236.62     1036.74   54454.85
# 1  2015-12-20          1.35      54876.98      674.28   44638.81
# 2  2015-12-13          0.93     118220.22      794.70  109149.67
# 3  2015-12-06          1.08      78992.15     1132.00   71976.41
# 4  2015-11-29          1.28      51039.60      941.48   43838.39
#
#    extra large Hass  Total Bags  Small Bags  Large Bags          type  year  \
# 0             48.16     8696.87     8603.62       93.25  conventional  2015
# 1             58.33     9505.56     9408.07       97.49  conventional  2015
# 2            130.50     8145.35     8042.21      103.14  conventional  2015
# 3             72.58     5811.16     5677.40      133.76  conventional  2015
# 4             75.78     6183.95     5986.26      197.69  conventional  2015
#
#    region
# 0  Albany
# 1  Albany
# 2  Albany
# 3  Albany
# 4  Albany

# %%
import seaborn as sns
sns.countplot(x="type" ,data=df )
plt.show()

# %%
sns.countplot(x="type" ,data=df ,hue="year" )
plt.show()

# %%
sns.relplot(x="Total Volume" , y ="AveragePrice",data=df ,kind="scatter",hue="type")
plt.show()

# %%
sns.pairplot(df.iloc[:,3:6],height=5.5)
