# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import re

# %%
df= pd.read_excel("E:\\My Courses\\attendance.xls",index=False)
df.head()
# Out:
#   Table 43. Average daily attendance (ADA) as a percentage of total enrollment, school day length, and school year length in public schools, by school level and state: 2007-08  \
# 0                                                NaN
# 1                                                NaN
# 2                                                  1
# 3                             United States ........
# 4                          Alabama .................
#
#                                           Unnamed: 1  Unnamed: 2  \
# 0  Total elementary, secondary, and combined elem...         NaN
# 1                       ADA as percent of enrollment         NaN
# 2                                                  2         NaN
# 3                                             93.079    0.218555
# 4                                            93.8124    1.237261
#
#                     Unnamed: 3  Unnamed: 4                   Unnamed: 5  \
# 0                          NaN         NaN                          NaN
# 1  Average hours in school day         NaN  Average days in school year
# 2                            3         NaN                            4
# 3                       6.6447    0.017650                          180
# 4                      7.02852    0.065621                          180
#
#    Unnamed: 6                    Unnamed: 7  Unnamed: 8  \
# 0         NaN                           NaN         NaN
# 1         NaN  Average hours in school year         NaN
# 2         NaN                             5         NaN
# 3    0.142993                       1192.65      3.0859
# 4    0.755110                       1266.62     12.3343
#
#                      Unnamed: 9  Unnamed: 10                  Unnamed: 11  \
# 0            Elementary schools          NaN                          NaN
# 1  ADA as percent of enrollment          NaN  Average hours in school day
# 2                             6          NaN                            7
# 3                        94.005     0.269369                      6.65606
# 4                       93.7764     1.839154                      7.03847
#
#    Unnamed: 12                   Unnamed: 13 Unnamed: 14  \
# 0          NaN             Secondary schools         NaN
# 1          NaN  ADA as percent of enrollment         NaN
# 2          NaN                             8         NaN
# 3     0.015998                       91.1181    0.432223
# 4     0.075944                        94.561     0.37928
#
#                    Unnamed: 15 Unnamed: 16
# 0                          NaN         NaN
# 1  Average hours in school day         NaN
# 2                            9         NaN
# 3                      6.59439    0.040308
# 4                      7.13724     0.17312

# %%
df.drop(0,inplace=True)
new_header = df.iloc[0] #grab the first row for the header
df = df[2:] #take the data less the header row
df.columns = new_header #set the header row as the df header
df.head()
# Out:
# 1                        NaN ADA as percent of enrollment       NaN  \
# 3     United States ........                       93.079  0.218555
# 4  Alabama .................                      93.8124  1.237261
# 5  Alaska ..................                      89.9176  1.215976
# 6  Arizona .................                       89.037  2.952601
# 7  Arkansas ................                      91.8271  1.352924
#
# 1 Average hours in school day       NaN Average days in school year       NaN  \
# 3                      6.6447  0.017650                         180  0.142993
# 4                     7.02852  0.065621                         180  0.755110
# 5                     6.47688  0.049882                         180  3.427735
# 6                     6.43369  0.091917                         181  1.678664
# 7                     6.88542  0.061468                         179  0.201577
#
# 1 Average hours in school year      NaN ADA as percent of enrollment  \
# 3                      1192.65   3.0859                       94.005
# 4                      1266.62  12.3343                      93.7764
# 5                      1162.91  22.8639                      91.2815
# 6                      1159.11  14.4327                      88.9044
# 7                      1228.89  10.6821                      92.0932
#
# 1       NaN Average hours in school day       NaN  \
# 3  0.269369                     6.65606  0.015998
# 4  1.839154                     7.03847  0.075944
# 5  1.563482                     6.48679  0.053082
# 6  3.905033                     6.44315  0.102053
# 7  2.091651                     6.93216  0.076546
#
# 1 ADA as percent of enrollment       NaN Average hours in school day       NaN
# 3                      91.1181  0.432223                     6.59439  0.040308
# 4                       94.561   0.37928                     7.13724   0.17312
# 5                      93.2409   1.57371                     6.24087  0.145993
# 6                      88.9797   3.22058                     6.36909  0.248824
# 7                       90.812   2.23155                     6.76751  0.095928

# %%
df.columns.values[0] = "State"
df.head()
# Out:
# 1                      State ADA as percent of enrollment       NaN  \
# 3     United States ........                       93.079  0.218555
# 4  Alabama .................                      93.8124  1.237261
# 5  Alaska ..................                      89.9176  1.215976
# 6  Arizona .................                       89.037  2.952601
# 7  Arkansas ................                      91.8271  1.352924
#
# 1 Average hours in school day       NaN Average days in school year       NaN  \
# 3                      6.6447  0.017650                         180  0.142993
# 4                     7.02852  0.065621                         180  0.755110
# 5                     6.47688  0.049882                         180  3.427735
# 6                     6.43369  0.091917                         181  1.678664
# 7                     6.88542  0.061468                         179  0.201577
#
# 1 Average hours in school year      NaN ADA as percent of enrollment  \
# 3                      1192.65   3.0859                       94.005
# 4                      1266.62  12.3343                      93.7764
# 5                      1162.91  22.8639                      91.2815
# 6                      1159.11  14.4327                      88.9044
# 7                      1228.89  10.6821                      92.0932
#
# 1       NaN Average hours in school day       NaN  \
# 3  0.269369                     6.65606  0.015998
# 4  1.839154                     7.03847  0.075944
# 5  1.563482                     6.48679  0.053082
# 6  3.905033                     6.44315  0.102053
# 7  2.091651                     6.93216  0.076546
#
# 1 ADA as percent of enrollment       NaN Average hours in school day       NaN
# 3                      91.1181  0.432223                     6.59439  0.040308
# 4                       94.561   0.37928                     7.13724   0.17312
# 5                      93.2409   1.57371                     6.24087  0.145993
# 6                      88.9797   3.22058                     6.36909  0.248824
# 7                       90.812   2.23155                     6.76751  0.095928

# %%
df = df.loc[:, df.columns.notnull()]
df.head(20)
# Out:
# 1                       State ADA as percent of enrollment  \
# 3      United States ........                       93.079
# 4   Alabama .................                      93.8124
# 5   Alaska ..................                      89.9176
# 6   Arizona .................                       89.037
# 7   Arkansas ................                      91.8271
# 8   California ..............                       93.241
# 9                         NaN                          NaN
# 10  Colorado ................                      93.8872
# 11  Connecticut .............                      87.9259
# 12  Delaware ................                      89.7706
# 13  District of Columbia ....                      91.2208
# 14  Florida .................                      92.6782
# 15                        NaN                          NaN
# 16  Georgia .................                      93.2662
# 17  Hawaii ..................                      90.7213
# 18  Idaho ...................                      92.3733
# 19  Illinois ................                      93.9705
# 20  Indiana .................                      95.6746
# 21                        NaN                          NaN
# 22  Iowa ....................                      94.7606
#
# 1  Average hours in school day Average days in school year  \
# 3                       6.6447                         180
# 4                      7.02852                         180
# 5                      6.47688                         180
# 6                      6.43369                         181
# 7                      6.88542                         179
# 8                      6.24064                         181
# 9                          NaN                         NaN
# 10                     7.00761                         171
# 11                     6.46655                         181
# 12                     6.67801                         181
# 13                     6.91375                         181
# 14                     6.42749                         184
# 15                         NaN                         NaN
# 16                     6.79186                         181
# 17                     6.25758                         179
# 18                     6.63155                         173
# 19                     6.50051                         177
# 20                     6.77208                         180
# 21                         NaN                         NaN
# 22                     6.85364                         180
#
# 1  Average hours in school year ADA as percent of enrollment  \
# 3                       1192.65                       94.005
# 4                       1266.62                      93.7764
# 5                       1162.91                      91.2815
# 6                       1159.11                      88.9044
# 7                       1228.89                      92.0932
# 8                       1128.77                      94.9314
# 9                           NaN                          NaN
# 10                       1199.3                      94.5353
# 11                      1173.08                      87.3722
# 12                      1208.23                      89.3634
# 13                      1255.96                      93.9313
# 14                      1183.57                      93.9625
# 15                          NaN                          NaN
# 16                      1229.21                       93.872
# 17                      1118.16                      90.8222
# 18                      1142.51                      91.9865
# 19                      1147.29                      95.3386
# 20                      1221.84                      95.8824
# 21                          NaN                          NaN
# 22                      1232.16                      96.2859
#
# 1  Average hours in school day ADA as percent of enrollment  \
# 3                      6.65606                      91.1181
# 4                      7.03847                       94.561
# 5                      6.48679                      93.2409
# 6                      6.44315                      88.9797
# 7                      6.93216                       90.812
# 8                      6.28974                      89.3609
# 9                          NaN                          NaN
# 10                     6.96058                      91.2429
# 11                     6.46963                      93.7472
# 12                     6.76638                            ‡
# 13                     6.91651                            ‡
# 14                     6.46352                      89.9067
# 15                         NaN                          NaN
# 16                     6.81855                      93.0693
# 17                     6.21725                            ‡
# 18                     6.59308                      92.5208
# 19                     6.49161                      89.9831
# 20                     6.71015                      95.0476
# 21                         NaN                          NaN
# 22                     6.89253                      90.4463
#
# 1  Average hours in school day
# 3                      6.59439
# 4                      7.13724
# 5                      6.24087
# 6                      6.36909
# 7                      6.76751
# 8                      6.14262
# 9                          NaN
# 10                     7.00875
# 11                     6.46219
# 12                     6.54407
# 13                           ‡
# 14                     6.31701
# 15                         NaN
# 16                     6.87159
# 17                           ‡
# 18                     6.66775
# 19                     6.49655
# 20                     6.96317
# 21                         NaN
# 22                     6.64382

# %%
df.dropna(inplace=True)
df.head(20)
# Out:
# 1                       State ADA as percent of enrollment  \
# 3      United States ........                       93.079
# 4   Alabama .................                      93.8124
# 5   Alaska ..................                      89.9176
# 6   Arizona .................                       89.037
# 7   Arkansas ................                      91.8271
# 8   California ..............                       93.241
# 10  Colorado ................                      93.8872
# 11  Connecticut .............                      87.9259
# 12  Delaware ................                      89.7706
# 13  District of Columbia ....                      91.2208
# 14  Florida .................                      92.6782
# 16  Georgia .................                      93.2662
# 17  Hawaii ..................                      90.7213
# 18  Idaho ...................                      92.3733
# 19  Illinois ................                      93.9705
# 20  Indiana .................                      95.6746
# 22  Iowa ....................                      94.7606
# 23  Kansas ..................                      95.3508
# 24  Kentucky ................                      93.0681
# 25  Louisiana ...............                      90.3495
#
# 1  Average hours in school day Average days in school year  \
# 3                       6.6447                         180
# 4                      7.02852                         180
# 5                      6.47688                         180
# 6                      6.43369                         181
# 7                      6.88542                         179
# 8                      6.24064                         181
# 10                     7.00761                         171
# 11                     6.46655                         181
# 12                     6.67801                         181
# 13                     6.91375                         181
# 14                     6.42749                         184
# 16                     6.79186                         181
# 17                     6.25758                         179
# 18                     6.63155                         173
# 19                     6.50051                         177
# 20                     6.77208                         180
# 22                     6.85364                         180
# 23                     6.98152                         178
# 24                     6.68771                         180
# 25                     7.07677                         178
#
# 1  Average hours in school year ADA as percent of enrollment  \
# 3                       1192.65                       94.005
# 4                       1266.62                      93.7764
# 5                       1162.91                      91.2815
# 6                       1159.11                      88.9044
# 7                       1228.89                      92.0932
# 8                       1128.77                      94.9314
# 10                       1199.3                      94.5353
# 11                      1173.08                      87.3722
# 12                      1208.23                      89.3634
# 13                      1255.96                      93.9313
# 14                      1183.57                      93.9625
# 16                      1229.21                       93.872
# 17                      1118.16                      90.8222
# 18                      1142.51                      91.9865
# 19                      1147.29                      95.3386
# 20                      1221.84                      95.8824
# 22                      1232.16                      96.2859
# 23                      1240.07                       95.897
# 24                      1201.77                      93.9503
# 25                      1262.86                      91.5498
#
# 1  Average hours in school day ADA as percent of enrollment  \
# 3                      6.65606                      91.1181
# 4                      7.03847                       94.561
# 5                      6.48679                      93.2409
# 6                      6.44315                      88.9797
# 7                      6.93216                       90.812
# 8                      6.28974                      89.3609
# 10                     6.96058                      91.2429
# 11                     6.46963                      93.7472
# 12                     6.76638                            ‡
# 13                     6.91651                            ‡
# 14                     6.46352                      89.9067
# 16                     6.81855                      93.0693
# 17                     6.21725                            ‡
# 18                     6.59308                      92.5208
# 19                     6.49161                      89.9831
# 20                     6.71015                      95.0476
# 22                     6.89253                      90.4463
# 23                     6.98478                      94.6401
# 24                     6.70708                      91.4904
# 25                     6.95146                      88.0394
#
# 1  Average hours in school day
# 3                      6.59439
# 4                      7.13724
# 5                      6.24087
# 6                      6.36909
# 7                      6.76751
# 8                      6.14262
# 10                     7.00875
# 11                     6.46219
# 12                     6.54407
# 13                           ‡
# 14                     6.31701
# 16                     6.87159
# 17                           ‡
# 18                     6.66775
# 19                     6.49655
# 20                     6.96317
# 22                     6.64382
# 23                     7.00631
# 24                     6.70971
# 25                     7.26485

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 3 to 63
# Data columns (total 9 columns):
# State                           52 non-null object
# ADA as percent of enrollment    52 non-null object
# Average hours in school day     52 non-null object
# Average days in school year     52 non-null object
# Average hours in school year    52 non-null object
# ADA as percent of enrollment    52 non-null object
# Average hours in school day     52 non-null object
# ADA as percent of enrollment    52 non-null object
# Average hours in school day     52 non-null object
# dtypes: object(9)
# memory usage: 4.1+ KB

# %%
df['State'] = df['State'].map(lambda x: x.replace('.',''))

# %%
df.index = np.arange(0, len(df))
df.head()
# Out:
# 1              State ADA as percent of enrollment Average hours in school day  \
# 0     United States                        93.079                      6.6447
# 1           Alabama                       93.8124                     7.02852
# 2            Alaska                       89.9176                     6.47688
# 3           Arizona                        89.037                     6.43369
# 4          Arkansas                       91.8271                     6.88542
#
# 1 Average days in school year Average hours in school year  \
# 0                         180                      1192.65
# 1                         180                      1266.62
# 2                         180                      1162.91
# 3                         181                      1159.11
# 4                         179                      1228.89
#
# 1 ADA as percent of enrollment Average hours in school day  \
# 0                       94.005                     6.65606
# 1                      93.7764                     7.03847
# 2                      91.2815                     6.48679
# 3                      88.9044                     6.44315
# 4                      92.0932                     6.93216
#
# 1 ADA as percent of enrollment Average hours in school day
# 0                      91.1181                     6.59439
# 1                       94.561                     7.13724
# 2                      93.2409                     6.24087
# 3                      88.9797                     6.36909
# 4                       90.812                     6.76751

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 51
# Data columns (total 9 columns):
# State                           52 non-null object
# ADA as percent of enrollment    52 non-null object
# Average hours in school day     52 non-null object
# Average days in school year     52 non-null object
# Average hours in school year    52 non-null object
# ADA as percent of enrollment    52 non-null object
# Average hours in school day     52 non-null object
# ADA as percent of enrollment    52 non-null object
# Average hours in school day     52 non-null object
# dtypes: object(9)
# memory usage: 4.1+ KB

# %%
df=df.iloc[:,1:].replace("‡",np.nan,inplace=True)
df.head()
# Out:
# 1  ADA as percent of enrollment  Average hours in school day  \
# 0                     93.078962                      6.64470
# 1                     93.812371                      7.02852
# 2                     89.917597                      6.47688
# 3                     89.036961                      6.43369
# 4                     91.827111                      6.88542
#
# 1  Average days in school year  Average hours in school year  \
# 0                          180                     1192.6472
# 1                          180                     1266.6205
# 2                          180                     1162.9084
# 3                          181                     1159.1144
# 4                          179                     1228.8881
#
# 1  ADA as percent of enrollment  Average hours in school day  \
# 0                     94.004983                     6.656056
# 1                     93.776375                     7.038473
# 2                     91.281537                     6.486785
# 3                     88.904393                     6.443155
# 4                     92.093201                     6.932160
#
# 1  ADA as percent of enrollment  Average hours in school day
# 0                     91.118081                     6.594394
# 1                     94.561001                     7.137239
# 2                     93.240876                     6.240865
# 3                     88.979716                     6.369092
# 4                     90.811952                     6.767508

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 51
# Data columns (total 8 columns):
# ADA as percent of enrollment    52 non-null float64
# Average hours in school day     52 non-null float64
# Average days in school year     52 non-null int64
# Average hours in school year    52 non-null float64
# ADA as percent of enrollment    52 non-null float64
# Average hours in school day     52 non-null float64
# ADA as percent of enrollment    47 non-null float64
# Average hours in school day     48 non-null float64
# dtypes: float64(7), int64(1)
# memory usage: 3.7 KB

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# 1
# ADA as percent of enrollment    0
# Average hours in school day     0
# Average days in school year     0
# Average hours in school year    0
# ADA as percent of enrollment    0
# Average hours in school day     0
# ADA as percent of enrollment    0
# Average hours in school day     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 0 to 51
# Data columns (total 8 columns):
# ADA as percent of enrollment    47 non-null float64
# Average hours in school day     47 non-null float64
# Average days in school year     47 non-null int64
# Average hours in school year    47 non-null float64
# ADA as percent of enrollment    47 non-null float64
# Average hours in school day     47 non-null float64
# ADA as percent of enrollment    47 non-null float64
# Average hours in school day     47 non-null float64
# dtypes: float64(7), int64(1)
# memory usage: 3.3 KB
