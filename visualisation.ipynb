# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("E:\\My Courses\\data.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
#we will drop last column because it's all values are missing 
df=df.iloc[:,:-1]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
# id                        569 non-null int64
# diagnosis                 569 non-null object
# radius_mean               569 non-null float64
# texture_mean              569 non-null float64
# perimeter_mean            569 non-null float64
# area_mean                 569 non-null float64
# smoothness_mean           569 non-null float64
# compactness_mean          569 non-null float64
# concavity_mean            569 non-null float64
# concave points_mean       569 non-null float64
# symmetry_mean             569 non-null float64
# fractal_dimension_mean    569 non-null float64
# radius_se                 569 non-null float64
# texture_se                569 non-null float64
# perimeter_se              569 non-null float64
# area_se                   569 non-null float64
# smoothness_se             569 non-null float64
# compactness_se            569 non-null float64
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# ### as  shown .. there is 357 Benign diagnoses and 212 malignant .
# ### lets show this with the plot

# %%
sns.countplot(df['diagnosis'])
plt.show()

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
#  #### bellow i will use the violin plot and i'll apply  also the boxplot to understand more about the violin plot .

# %%
sns.violinplot(x="area_mean", data=df)

# %%
df.boxplot(column=["area_mean"])
plt.show()

# %% [markdown]
# ### lets show some correlation between our features.

# %%
sns.relplot(x="radius_mean",y="texture_mean" , hue="diagnosis" ,data=df, kind ="scatter")
plt.show()

# %%
#here we see that there is a strong correlation between this two columns. also i splitted  the diagnosed feature. 
sns.relplot(x="radius_mean",y="perimeter_mean" , hue="diagnosis",style="diagnosis" ,data=df, kind ="scatter")
plt.show()

# %%
sns.relplot(x="radius_mean",y="smoothness_mean" , hue="diagnosis" ,data=df, kind ="scatter")
plt.show()
#this is a weak correlation

# %%
sns.relplot(x="radius_mean",y="compactness_mean" , hue="diagnosis" ,data=df, kind ="scatter")
plt.show()

# %%
sns.relplot(x="perimeter_mean",y="compactness_mean" , hue="diagnosis" ,data=df, kind ="scatter")
plt.show()

# %%
sns.relplot(x="perimeter_mean",y="texture_mean" , hue="diagnosis" ,data=df, kind ="scatter")
plt.show()

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ### here i'll select only ean columnsand apply a correlation heatmap to see tha crrelation between them clearly.
# ### we can drop the feature that has a strong correlation with another couse it will do the same role in the model..
# #### Ex: "area_mean" ," perimeter_mean" and "radius_mean " have 0.99 corr so we could drop two of them
# #### also "concavity_mean " and "concave points_mean" so we could drop "concave points_mean"

# %%
mean_df=df.iloc[:,2:12]
plt.figure(figsize=(14,7))
sns.heatmap(mean_df.corr(), annot=True)

# %%
mean_df.drop(['perimeter_mean','area_mean','concave points_mean'], axis=1, inplace=True)
plt.figure(figsize=(14,7))
sns.heatmap(mean_df.corr(), annot=True)
#so this looks nice :) .
